# %%
import pandas as pd

df = pd.read_csv('/Users/francisco/Library/CloudStorage/OneDrive-Pessoal/Documentos/LabMol/SOFIA/MQ/Paper OdorSight/DATA/Curation/curated_dataset_final.csv')
df
# Out:
#       Outcome                                        SMILES  \
# 0           0       [O]=[Al][O][Si](=O)O[Si](=O)[O][Al]=[O]
# 1           0                                N#[C][Hg][C]#N
# 2           0                                  [Cl][Cr][Cl]
# 3           0                                  [Cl][Hg][Cl]
# 4           0                                  [Cl][Ni][Cl]
# ...       ...                                           ...
# 4254        0                              O=[N+]([O-])[O-]
# 4255        0                                      O=[Si]=O
# 4256        1                                    O=[O+][O-]
# 4257        0                      [O-][Si]([O-])([O-])[O-]
# 4258        0  [O-][Si]1([O-])O[Si]2(O1)O[Si]([O-])([O-])O2
#
#                                                   InChI
# 0     InChI=1S/2Al.O5Si2.2O/c;;1-6(2)5-7(3)4;;/q2*+1...
# 1                               InChI=1S/2CN.Hg/c2*1-2;
# 2                     InChI=1S/2ClH.Cr/h2*1H;/q;;+2/p-2
# 3                     InChI=1S/2ClH.Hg/h2*1H;/q;;+2/p-2
# 4                     InChI=1S/2ClH.Ni/h2*1H;/q;;+2/p-2
# ...                                                 ...
# 4254                          InChI=1S/NO3/c2-1(3)4/q-1
# 4255                               InChI=1S/O2Si/c1-3-2
# 4256                                 InChI=1S/O3/c1-3-2
# 4257                       InChI=1S/O4Si/c1-5(2,3)4/q-4
# 4258   InChI=1S/O8Si3/c1-9(2)5-11(6-9)7-10(3,4)8-11/q-4
#
# [4259 rows x 3 columns]

# %%
x = df['SMILES']
y = df['Outcome']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, train_size=0.8, random_state=42, stratify=y)

df_test = pd.DataFrame({'SMILES': X_test, 'Outcome': y_test})
df_test.to_csv('test_manual.csv', index=False)
